# %%
# 1 - DATA MANIPULATION
import pandas as pd
import numpy as np

# 2 - DATA VISUALISATION
import matplotlib.pyplot as plt
import seaborn as sns

# 3 - FEATURE ENGINEERING
import string #punctuation
import nltk #English language stopwords
nltk.download('punkt')
nltk.download('stopwords')
from nltk.corpus import stopwords
from collections import Counter
import re
import spacy
nlp = spacy.load("en_core_web_sm")

# !pip install ydata-profiling
# !pip install ipywidgets
# Out:
# [nltk_data] Downloading package punkt to /Users/christine/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/christine/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# # 1. Prepare the dataset

# %%
file_path = '/Users/christine/code/ChristineSi/neuroCraft/raw_data/CLEAR.csv'
# Load the CSV file into a Pandas DataFrame
df = pd.read_csv(file_path)
# Display the DataFrame
df.head()
# Out:
#       ID  Last Changed            Author  \
# 0  400.0           NaN     Carolyn Wells
# 1  401.0           NaN     Carolyn Wells
# 2  402.0           NaN     Carolyn Wells
# 3  403.0           NaN  CHARLES KINGSLEY
# 4  404.0           NaN  Charles Kingsley
#
#                                                Title  \
# 0                                    Patty's Suitors
# 1                      Two Little Women on a Holiday
# 2                                      Patty Blossom
# 3     THE WATER-BABIES\nA Fairy Tale for a Land-Baby
# 4  HOW THE ARGONAUTS WERE DRIVEN INTO THE UNKNOWN...
#
#                                           Anthology  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4  The Heroes\nor Greek Fairy Tales for my Children
#
#                                                  URL     Source  Pub Year  \
# 0  http://www.gutenberg.org/cache/epub/5631/pg563...  gutenberg    1914.0
# 1  http://www.gutenberg.org/cache/epub/5893/pg589...  gutenberg    1917.0
# 2  http://www.gutenberg.org/cache/epub/20945/pg20...  gutenberg    1917.0
# 3  http://www.gutenberg.org/files/25564/25564-h/2...  gutenberg    1863.0
# 4  http://www.gutenberg.org/files/677/677-h/677-h...  gutenberg    1889.0
#
#   Category Location  ...  CAREC_M     CARES     CML2RI  firstPlace_pred  \
# 0      Lit      mid  ...  0.11952  0.457534  12.097815        -0.383831
# 1      Lit      mid  ...  0.04921  0.462510  22.550179        -0.260307
# 2      Lit      mid  ...  0.09724  0.369259  18.125279        -0.615037
# 3      Lit      mid  ...  0.08856  0.390759  10.959460        -1.528806
# 4      Lit      mid  ...  0.08798  0.389226   3.195960        -1.335586
#
#   secondPlace_pred  thirdPlace_pred  fourthPlace_pred  fifthPlace_pred  \
# 0        -0.283604        -0.346879         -0.281620        -0.247767
# 1        -0.209960        -0.061565         -0.234231        -0.201347
# 2        -0.530600        -0.527847         -0.550180        -0.565762
# 3        -1.525546        -1.471455         -1.265776        -1.422547
# 4        -1.321922        -1.163985         -1.122501        -1.185518
#
#   sixthPlace_pred  Kaggle split
# 0       -0.289945         Train
# 1       -0.156156         Train
# 2       -0.538852         Train
# 3       -1.393155          Test
# 4       -1.271324         Train
#
# [5 rows x 40 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4726 entries, 0 to 4725
# Data columns (total 40 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   ID                                  4724 non-null   float64
#  1   Last Changed                        139 non-null    float64
#  2   Author                              4724 non-null   object
#  3   Title                               4724 non-null   object
#  4   Anthology                           2712 non-null   object
#  5   URL                                 4724 non-null   object
#  6   Source                              4724 non-null   object
#  7   Pub Year                            4715 non-null   float64
#  8   Category                            4724 non-null   object
#  9   Location                            4724 non-null   object
#  10  License                             4724 non-null   object
#  11  MPAA
# Max                            4724 non-null   object
#  12  MPAA
# #Max                          4724 non-null   float64
#  13  MPAA
# #Avg                           4724 non-null   float64
#  14  Excerpt                             4724 non-null   object
#  15  Google
# WC                           4724 non-null   float64
#  16  Joon
# WC v1                          4724 non-null   float64
#  17  British WC                          4724 non-null   float64
#  18  British Words                       444 non-null    object
#  19  Sentence
# Count v1                   4724 non-null   float64
#  20  Sentence
# Count v2                   4724 non-null   float64
#  21  Paragraphs                          4724 non-null   float64
#  22  BT Easiness                         4724 non-null   float64
#  23  BT s.e.                             4724 non-null   float64
#  24  Flesch-Reading-Ease                 4724 non-null   float64
#  25  Flesch-Kincaid-Grade-Level          4724 non-null   float64
#  26  Automated Readability Index         4724 non-null   float64
#  27  SMOG Readability                    4724 non-null   float64
#  28  New Dale-Chall Readability Formula  4724 non-null   float64
#  29  CAREC                               4724 non-null   float64
#  30  CAREC_M                             4724 non-null   float64
#  31  CARES                               4724 non-null   float64
#  32  CML2RI                              4724 non-null   float64
#  33  firstPlace_pred                     4724 non-null   float64
#  34  secondPlace_pred                    4724 non-null   float64
#  35  thirdPlace_pred                     4724 non-null   float64
#  36  fourthPlace_pred                    4724 non-null   float64
#  37  fifthPlace_pred                     4724 non-null   float64
#  38  sixthPlace_pred                     4724 non-null   float64
#  39  Kaggle split                        4724 non-null   object
# dtypes: float64(28), object(12)
# memory usage: 1.4+ MB

# %%
df.columns
# Out:
# Index(['ID', 'Last Changed', 'Author', 'Title', 'Anthology', 'URL', 'Source',
#        'Pub Year', 'Category', 'Location', 'License', 'MPAA\nMax',
#        'MPAA \n#Max', 'MPAA\n#Avg', 'Excerpt', 'Google\nWC', 'Joon\nWC v1',
#        'British WC', 'British Words', 'Sentence\nCount v1',
#        'Sentence\nCount v2', 'Paragraphs', 'BT Easiness', 'BT s.e.',
#        'Flesch-Reading-Ease', 'Flesch-Kincaid-Grade-Level',
#        'Automated Readability Index', 'SMOG Readability',
#        'New Dale-Chall Readability Formula', 'CAREC', 'CAREC_M', 'CARES',
#        'CML2RI', 'firstPlace_pred', 'secondPlace_pred', 'thirdPlace_pred',
#        'fourthPlace_pred', 'fifthPlace_pred', 'sixthPlace_pred',
#        'Kaggle split'],
#       dtype='object')

# %%
columns_to_drop = ['Last Changed', 'Anthology', 'URL', 'License','MPAA \n#Max', 'MPAA\n#Avg',
                   'firstPlace_pred', 'secondPlace_pred', 'thirdPlace_pred',
                   'fourthPlace_pred', 'fifthPlace_pred', 'sixthPlace_pred']

# Drop the specified columns
df = df.drop(columns=columns_to_drop)
df.head()
# Out:
#       ID            Author                                              Title  \
# 0  400.0     Carolyn Wells                                    Patty's Suitors
# 1  401.0     Carolyn Wells                      Two Little Women on a Holiday
# 2  402.0     Carolyn Wells                                      Patty Blossom
# 3  403.0  CHARLES KINGSLEY     THE WATER-BABIES\nA Fairy Tale for a Land-Baby
# 4  404.0  Charles Kingsley  HOW THE ARGONAUTS WERE DRIVEN INTO THE UNKNOWN...
#
#       Source  Pub Year Category Location MPAA\nMax  \
# 0  gutenberg    1914.0      Lit      mid         G
# 1  gutenberg    1917.0      Lit      mid        PG
# 2  gutenberg    1917.0      Lit      mid        PG
# 3  gutenberg    1863.0      Lit      mid     PG-13
# 4  gutenberg    1889.0      Lit      mid        PG
#
#                                              Excerpt  Google\nWC  ...  \
# 0  When the young people returned to the ballroom...       174.0  ...
# 1  All through dinner time, Mrs. Fayre was somewh...       164.0  ...
# 2  As Roger had predicted, the snow departed as q...       162.0  ...
# 3  Mr. Grimes was to come up next morning to Sir ...       159.0  ...
# 4  And outside before the palace a great garden w...       163.0  ...
#
#    Flesch-Reading-Ease  Flesch-Kincaid-Grade-Level  \
# 0                81.70                        5.95
# 1                80.26                        4.86
# 2                79.04                        6.03
# 3                44.77                       20.51
# 4                68.07                       12.06
#
#   Automated Readability Index  SMOG Readability  \
# 0                        7.37               8.0
# 1                        4.16               7.0
# 2                        5.81               9.0
# 3                       24.87              12.0
# 4                       15.47               8.0
#
#    New Dale-Chall Readability Formula    CAREC  CAREC_M     CARES     CML2RI  \
# 0                                6.55  0.12102  0.11952  0.457534  12.097815
# 1                                6.25  0.04921  0.04921  0.462510  22.550179
# 2                                7.31  0.10172  0.09724  0.369259  18.125279
# 3                                8.56  0.07491  0.08856  0.390759  10.959460
# 4                                7.00  0.06356  0.08798  0.389226   3.195960
#
#    Kaggle split
# 0         Train
# 1         Train
# 2         Train
# 3          Test
# 4         Train
#
# [5 rows x 28 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4726 entries, 0 to 4725
# Data columns (total 28 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   ID                                  4724 non-null   float64
#  1   Author                              4724 non-null   object
#  2   Title                               4724 non-null   object
#  3   Source                              4724 non-null   object
#  4   Pub Year                            4715 non-null   float64
#  5   Category                            4724 non-null   object
#  6   Location                            4724 non-null   object
#  7   MPAA
# Max                            4724 non-null   object
#  8   Excerpt                             4724 non-null   object
#  9   Google
# WC                           4724 non-null   float64
#  10  Joon
# WC v1                          4724 non-null   float64
#  11  British WC                          4724 non-null   float64
#  12  British Words                       444 non-null    object
#  13  Sentence
# Count v1                   4724 non-null   float64
#  14  Sentence
# Count v2                   4724 non-null   float64
#  15  Paragraphs                          4724 non-null   float64
#  16  BT Easiness                         4724 non-null   float64
#  17  BT s.e.                             4724 non-null   float64
#  18  Flesch-Reading-Ease                 4724 non-null   float64
#  19  Flesch-Kincaid-Grade-Level          4724 non-null   float64
#  20  Automated Readability Index         4724 non-null   float64
#  21  SMOG Readability                    4724 non-null   float64
#  22  New Dale-Chall Readability Formula  4724 non-null   float64
#  23  CAREC                               4724 non-null   float64
#  24  CAREC_M                             4724 non-null   float64
#  25  CARES                               4724 non-null   float64
#  26  CML2RI                              4724 non-null   float64
#  27  Kaggle split                        4724 non-null   object
# dtypes: float64(19), object(9)
# memory usage: 1.0+ MB

# %%
df.Location.value_counts()
# Out:
# Location
# mid      3470
# start    1024
# whole     122
# end       108
# Name: count, dtype: int64

# %%
profile = ProfileReport(df, title="Profiling Report")
profile.to_widgets()    #it takes 3-4 min
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:208: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_valid_dtype = pdt.is_categorical_dtype(series) and not pdt.is_bool_dtype(
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:208: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_valid_dtype = pdt.is_categorical_dtype(series) and not pdt.is_bool_dtype(
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:125: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   not pdt.is_categorical_dtype(series)
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:125: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   not pdt.is_categorical_dtype(series)
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:208: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_valid_dtype = pdt.is_categorical_dtype(series) and not pdt.is_bool_dtype(
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:125: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   not pdt.is_categorical_dtype(series)
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:208: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_valid_dtype = pdt.is_categorical_dtype(series) and not pdt.is_bool_dtype(
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:125: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   not pdt.is_categorical_dtype(series)
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:208: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_valid_dtype = pdt.is_categorical_dtype(series) and not pdt.is_bool_dtype(
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:125: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   not pdt.is_categorical_dtype(series)
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:125: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   not pdt.is_categorical_dtype(series)
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:208: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_valid_dtype = pdt.is_categorical_dtype(series) and not pdt.is_bool_dtype(
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset_relations.py:34: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pdt.is_categorical_dtype(series):
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset_relations.py:34: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pdt.is_categorical_dtype(series):
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset_relations.py:34: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pdt.is_categorical_dtype(series):
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset_relations.py:34: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pdt.is_categorical_dtype(series):
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:208: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_valid_dtype = pdt.is_categorical_dtype(series) and not pdt.is_bool_dtype(
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset_relations.py:34: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pdt.is_categorical_dtype(series):
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset_relations.py:34: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pdt.is_categorical_dtype(series):
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:125: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   not pdt.is_categorical_dtype(series)
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:208: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_valid_dtype = pdt.is_categorical_dtype(series) and not pdt.is_bool_dtype(
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:125: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   not pdt.is_categorical_dtype(series)
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset_relations.py:34: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pdt.is_categorical_dtype(series):
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:208: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_valid_dtype = pdt.is_categorical_dtype(series) and not pdt.is_bool_dtype(
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:125: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   not pdt.is_categorical_dtype(series)
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset_relations.py:34: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pdt.is_categorical_dtype(series):
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset_relations.py:34: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pdt.is_categorical_dtype(series):
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:208: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_valid_dtype = pdt.is_categorical_dtype(series) and not pdt.is_bool_dtype(
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:125: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   not pdt.is_categorical_dtype(series)
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset_relations.py:34: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pdt.is_categorical_dtype(series):
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:208: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_valid_dtype = pdt.is_categorical_dtype(series) and not pdt.is_bool_dtype(
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:125: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   not pdt.is_categorical_dtype(series)
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset_relations.py:34: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pdt.is_categorical_dtype(series):
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:208: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_valid_dtype = pdt.is_categorical_dtype(series) and not pdt.is_bool_dtype(
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:208: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_valid_dtype = pdt.is_categorical_dtype(series) and not pdt.is_bool_dtype(
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:125: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   not pdt.is_categorical_dtype(series)
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:125: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   not pdt.is_categorical_dtype(series)
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset_relations.py:34: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pdt.is_categorical_dtype(series):
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:208: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_valid_dtype = pdt.is_categorical_dtype(series) and not pdt.is_bool_dtype(
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:208: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_valid_dtype = pdt.is_categorical_dtype(series) and not pdt.is_bool_dtype(
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:208: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_valid_dtype = pdt.is_categorical_dtype(series) and not pdt.is_bool_dtype(
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset_relations.py:34: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pdt.is_categorical_dtype(series):
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:125: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   not pdt.is_categorical_dtype(series)
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:208: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_valid_dtype = pdt.is_categorical_dtype(series) and not pdt.is_bool_dtype(
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset_relations.py:34: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pdt.is_categorical_dtype(series):
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:208: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_valid_dtype = pdt.is_categorical_dtype(series) and not pdt.is_bool_dtype(
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:208: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_valid_dtype = pdt.is_categorical_dtype(series) and not pdt.is_bool_dtype(
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:125: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   not pdt.is_categorical_dtype(series)
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset_relations.py:34: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pdt.is_categorical_dtype(series):
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:208: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_valid_dtype = pdt.is_categorical_dtype(series) and not pdt.is_bool_dtype(
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:208: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_valid_dtype = pdt.is_categorical_dtype(series) and not pdt.is_bool_dtype(
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:208: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_valid_dtype = pdt.is_categorical_dtype(series) and not pdt.is_bool_dtype(
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:208: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_valid_dtype = pdt.is_categorical_dtype(series) and not pdt.is_bool_dtype(
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:208: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_valid_dtype = pdt.is_categorical_dtype(series) and not pdt.is_bool_dtype(
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:208: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_valid_dtype = pdt.is_categorical_dtype(series) and not pdt.is_bool_dtype(
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:208: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_valid_dtype = pdt.is_categorical_dtype(series) and not pdt.is_bool_dtype(
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:208: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_valid_dtype = pdt.is_categorical_dtype(series) and not pdt.is_bool_dtype(
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:208: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_valid_dtype = pdt.is_categorical_dtype(series) and not pdt.is_bool_dtype(
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:208: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_valid_dtype = pdt.is_categorical_dtype(series) and not pdt.is_bool_dtype(
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:208: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_valid_dtype = pdt.is_categorical_dtype(series) and not pdt.is_bool_dtype(
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:208: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_valid_dtype = pdt.is_categorical_dtype(series) and not pdt.is_bool_dtype(
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:125: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   not pdt.is_categorical_dtype(series)
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset_relations.py:34: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pdt.is_categorical_dtype(series):
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:208: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_valid_dtype = pdt.is_categorical_dtype(series) and not pdt.is_bool_dtype(
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset.py:125: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   not pdt.is_categorical_dtype(series)
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/typeset_relations.py:34: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pdt.is_categorical_dtype(series):
# /Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/correlations.py:66: UserWarning: There was an attempt to calculate the auto correlation, but this failed.
# To hide this warning, disable the calculation
# (using `df.profile_report(correlations={"auto": {"calculate": False}})`
# If this is problematic for your use case, please report this as an issue:
# https://github.com/ydataai/ydata-profiling/issues
# (include the error message: 'Function <code object pandas_auto_compute at 0x2c3e76ef0, file "/Users/christine/.pyenv/versions/3.10.6/envs/neuroCraft/lib/python3.10/site-packages/ydata_profiling/model/pandas/correlations_pandas.py", line 164>')
#   warnings.warn(
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
# Save the profile report as an HTML file
profile.to_file("profile_report.html")
#profile.to_file("profile_report.json")
# Out:
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# Render JSON:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# ## Check for missing values

# %%
missing_values_count = df.isnull().sum()
columns_with_missing_values = missing_values_count[missing_values_count > 0].index

print(f"Columns with missing values: {columns_with_missing_values}")
# Out:
# Columns with missing values: Index(['ID', 'Author', 'Title', 'Source', 'Pub Year', 'Category', 'Location',
#        'MPAA\nMax', 'Excerpt', 'Google\nWC', 'Joon\nWC v1', 'British WC',
#        'British Words', 'Sentence\nCount v1', 'Sentence\nCount v2',
#        'Paragraphs', 'BT Easiness', 'BT s.e.', 'Flesch-Reading-Ease',
#        'Flesch-Kincaid-Grade-Level', 'Automated Readability Index',
#        'SMOG Readability', 'New Dale-Chall Readability Formula', 'CAREC',
#        'CAREC_M', 'CARES', 'CML2RI', 'Kaggle split'],
#       dtype='object')

# %%
# Filter columns with missing values
columns_with_missing_values = missing_values_count[missing_values_count > 0]
# Print columns and their respective counts of missing values
for column in columns_with_missing_values.index:
    count = columns_with_missing_values[column]
    print(f"Column '{column}': {count} missing values")
# Out:
# Column 'ID': 2 missing values
# Column 'Author': 2 missing values
# Column 'Title': 2 missing values
# Column 'Source': 2 missing values
# Column 'Pub Year': 11 missing values
# Column 'Category': 2 missing values
# Column 'Location': 2 missing values
# Column 'MPAA
# Max': 2 missing values
# Column 'Excerpt': 2 missing values
# Column 'Google
# WC': 2 missing values
# Column 'Joon
# WC v1': 2 missing values
# Column 'British WC': 2 missing values
# Column 'British Words': 4282 missing values
# Column 'Sentence
# Count v1': 2 missing values
# Column 'Sentence
# Count v2': 2 missing values
# Column 'Paragraphs': 2 missing values
# Column 'BT Easiness': 2 missing values
# Column 'BT s.e.': 2 missing values
# Column 'Flesch-Reading-Ease': 2 missing values
# Column 'Flesch-Kincaid-Grade-Level': 2 missing values
# Column 'Automated Readability Index': 2 missing values
# Column 'SMOG Readability': 2 missing values
# Column 'New Dale-Chall Readability Formula': 2 missing values
# Column 'CAREC': 2 missing values
# Column 'CAREC_M': 2 missing values
# Column 'CARES': 2 missing values
# Column 'CML2RI': 2 missing values
# Column 'Kaggle split': 2 missing values

# %% [markdown]
# We don't have British Words on each text fragment. We decide to drop this column.

# %%
df.drop(columns=['British Words'])
# Verify that the column has been dropped
print("Columns after dropping 'British Words':", df.columns)
# Out:
# Columns after dropping 'British Words': Index(['ID', 'Author', 'Title', 'Source', 'Pub Year', 'Category', 'Location',
#        'MPAA\nMax', 'Excerpt', 'Google\nWC', 'Joon\nWC v1', 'British WC',
#        'British Words', 'Sentence\nCount v1', 'Sentence\nCount v2',
#        'Paragraphs', 'BT Easiness', 'BT s.e.', 'Flesch-Reading-Ease',
#        'Flesch-Kincaid-Grade-Level', 'Automated Readability Index',
#        'SMOG Readability', 'New Dale-Chall Readability Formula', 'CAREC',
#        'CAREC_M', 'CARES', 'CML2RI', 'Kaggle split'],
#       dtype='object')

# %% [markdown]
# ## Check for duplicates

# %%
#Let's check the duplicates (profile reports says 0 duplicated rows)
duplicate_rows = df[df.duplicated()]

# Check if there are any duplicate rows
if duplicate_rows.shape[0] == 0:
    print("There are no duplicate rows in the DataFrame.")
else:
    print(f"There are {duplicate_rows.shape[0]} duplicate rows in the DataFrame.")
# Out:
# There are 1 duplicate rows in the DataFrame.

# %% [markdown]
# Let's explore the numeric, text and categorical variables:

# %%
numeric_variables = df.select_dtypes(include=['number'])

# Explore summary statistics for numeric variables
numeric_summary = numeric_variables.describe()
print("Summary statistics for numeric variables:")
print(numeric_summary)
# Out:
# Summary statistics for numeric variables:
#                 ID     Pub Year   Google\nWC  Joon\nWC v1   British WC  \
# count  4724.000000  4715.000000  4724.000000  4724.000000  4724.000000
# mean   4366.347163  1937.886957   171.960203   176.925487     0.129340
# std    1896.363710    60.506795    16.988921    18.173592     0.471049
# min     400.000000  1728.000000   125.000000   135.000000     0.000000
# 25%    2769.750000  1884.000000   158.000000   162.000000     0.000000
# 50%    4483.500000  1915.000000   174.000000   178.000000     0.000000
# 75%    5939.250000  2016.000000   186.000000   191.000000     0.000000
# max    8031.000000  2020.000000   205.000000   220.000000     9.000000
#
#        Sentence\nCount v1  Sentence\nCount v2   Paragraphs  BT Easiness  \
# count         4724.000000         4724.000000  4724.000000  4724.000000
# mean             9.570703            9.752329     2.542337    -0.957639
# std              4.640162            4.681339     1.866298     1.033656
# min              2.000000            2.000000     1.000000    -3.676268
# 25%              7.000000            7.000000     1.000000    -1.696555
# 50%              8.000000            9.000000     2.000000    -0.909094
# 75%             11.000000           11.000000     3.000000    -0.203428
# max             41.000000           41.000000    20.000000     1.711390
#
#            BT s.e.  Flesch-Reading-Ease  Flesch-Kincaid-Grade-Level  \
# count  4724.000000          4724.000000                 4724.000000
# mean      0.491216            65.231230                    9.508315
# std       0.033999            18.178085                    4.325918
# min       0.000000           -28.990000                   -1.040000
# 25%       0.468663            53.627500                    6.560000
# 50%       0.484452            66.330000                    9.350000
# 75%       0.506143            78.650000                   11.972500
# max       0.649671           114.030000                   42.640000
#
#        Automated Readability Index  SMOG Readability  \
# count                  4724.000000       4724.000000
# mean                     10.264630         10.198582
# std                       5.240155          3.263997
# min                      -3.090000          0.000000
# 25%                       6.820000          8.000000
# 50%                      10.050000         10.000000
# 75%                      13.210000         12.000000
# max                      51.590000         18.000000
#
#        New Dale-Chall Readability Formula        CAREC      CAREC_M  \
# count                         4724.000000  4724.000000  4724.000000
# mean                             7.674784     0.165342     0.166390
# std                              1.944550     0.109087     0.105761
# min                              0.280000    -0.168350    -0.142080
# 25%                              6.557500     0.085567     0.089680
# 50%                              7.625000     0.162990     0.164900
# 75%                              8.870000     0.240968     0.238890
# max                             14.190000     0.599770     0.594850
#
#              CARES       CML2RI
# count  4724.000000  4724.000000
# mean      0.467638    15.465939
# std       0.099253     7.430752
# min       0.125376    -4.380899
# 25%       0.397897    10.102327
# 50%       0.467207    15.054398
# 75%       0.532723    20.131281
# max       0.794805    47.214743

# %% [markdown]
# Pub Year: 1728-2020\
# Google WC, Joon WC v1, British WC: word counts from different sources

# %% [markdown]
# ## Check for outliers

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Add this line to enable inline plotting in Jupyter/IPython
# %matplotlib inline

plt.figure(figsize=(10, 6))
sns.boxplot(x='BT Easiness', data=df)
plt.title('Boxplot of BT Easiness')
plt.show()

# %%
text_variables = df.select_dtypes(include=['object'])

# Explore unique values and word frequency for text variables
for column in text_variables.columns:
    unique_values = text_variables[column].unique()
    word_frequency = text_variables[column].str.split().explode().value_counts()

    print(f"Column: {column}")
    print("Unique values:", unique_values)
    print("Word frequency:")
    print(word_frequency)
    print("\n")
# Out:
# Column: Author
# Unique values: ['Carolyn Wells' 'CHARLES KINGSLEY' 'Charles Kingsley' ... 'Stephen Whitt'
#  'wikijunior' nan]
# Word frequency:
# Author
# wiki         275
# simple       275
# wikipedia    274
# ?            271
# &            173
#             ...
# Happy          1
# Kwamie         1
# Ofori          1
# Da             1
# Mhlophe        1
# Name: count, Length: 4848, dtype: int64
#
#
# Column: Title
# Unique values: ["Patty's Suitors" 'Two Little Women on a Holiday' 'Patty Blossom' ...
#  'Solids' 'Anials' nan]
# Word frequency:
# Title
# The          946
# the          777
# THE          752
# of           729
# and          454
#             ...
# Herd           1
# Pet            1
# rooster        1
# Fireflies      1
# Anials         1
# Name: count, Length: 8467, dtype: int64
#
#
# Column: Source
# Unique values: ['gutenberg' 'simple.wikipedia' 'kids.frontiersin' 'wikipedia'
#  'africanstorybook' 'ck12' 'freekidsbooks' 'commonlit' 'emedia.uen.org'
#  'digitallibrary' 'ukuqonda.co.za' 'openschool.bc.ca' 'online-literature'
#  'wikisource' 'drive.google.com' 'static.ehe.osu.edu' 'beyondweather'
#  'beyondpenguins' 'wikibooks' nan]
# Word frequency:
# Source
# gutenberg             2916
# kids.frontiersin       458
# commonlit              296
# simple.wikipedia       275
# wikipedia              274
# africanstorybook       250
# online-literature       95
# digitallibrary          61
# freekidsbooks           50
# static.ehe.osu.edu      16
# wikibooks               13
# ukuqonda.co.za           4
# ck12                     4
# drive.google.com         4
# emedia.uen.org           3
# beyondpenguins           2
# openschool.bc.ca         1
# wikisource               1
# beyondweather            1
# Name: count, dtype: int64
#
#
# Column: Category
# Unique values: ['Lit' 'Info' nan]
# Word frequency:
# Category
# Lit     2420
# Info    2304
# Name: count, dtype: int64
#
#
# Column: Location
# Unique values: ['mid' 'start' 'end' 'whole' nan]
# Word frequency:
# Location
# mid      3470
# start    1024
# whole     122
# end       108
# Name: count, dtype: int64
#
#
# Column: MPAA
# Max
# Unique values: ['G' 'PG' 'PG-13' 'R' nan]
# Word frequency:
# MPAA\nMax
# G        3706
# PG        928
# PG-13      87
# R           3
# Name: count, dtype: int64
#
#
# Column: Excerpt
# Unique values: ['When the young people returned to the ballroom, it presented a decidedly changed appearance. Instead of an interior scene, it was a winter landscape.\nThe floor was covered with snow-white canvas, not laid on smoothly, but rumpled over bumps and hillocks, like a real snow field. The numerous palms and evergreens that had decorated the room, were powdered with flour and strewn with tufts of cotton, like snow. Also diamond dust had been lightly sprinkled on them, and glittering crystal icicles hung from the branches.\nAt each end of the room, on the wall, hung a beautiful bear-skin rug.\nThese rugs were for prizes, one for the girls and one for the boys. And this was the game.\nThe girls were gathered at one end of the room and the boys at the other, and one end was called the North Pole, and the other the South Pole. Each player was given a small flag which they were to plant on reaching the Pole.\nThis would have been an easy matter, but each traveller was obliged to wear snowshoes.'
#  'All through dinner time, Mrs. Fayre was somewhat silent, her eyes resting on Dolly with a wistful, uncertain expression. She wanted to give the child the pleasure she craved, but she had hard work to bring herself to the point of overcoming her own objections.\nAt last, however, when the meal was nearly over, she smiled at her little daughter, and said, "All right, Dolly, you may go."\n"Oh, mother!" Dolly cried, overwhelmed with sudden delight. "Really?\nOh, I am so glad! Are you sure you\'re willing?"\n"I\'ve persuaded myself to be willing, against my will," returned Mrs. Fayre, whimsically. "I confess I just hate to have you go, but I can\'t bear to deprive you of the pleasure trip. And, as you say, it would also keep Dotty at home, and so, altogether, I think I shall have to give in."\n"Oh, you angel mother! You blessed lady! How good you are!" And Dolly flew around the table and gave her mother a hug that nearly suffocated her.'
#  'As Roger had predicted, the snow departed as quickly as it came, and two days after their sleigh ride there was scarcely a vestige of white on the ground. Tennis was again possible and a great game was in progress on the court at Pine Laurel. Patty and Roger were playing against Elise and Sam Blaney, and the pairs were well matched.\nBut the long-contested victory finally went against Patty, and she laughingly accepted defeat.\n"Only because Patty\'s not quite back on her game yet," Roger defended; "this child has been on the sick list, you know, Sam, and she isn\'t up to her own mark."\n"Well, I like that!" cried Patty; "suppose you bear half the blame, Roger. You see, Mr. Blaney, he is so absorbed in his own Love Game, he can\'t play with his old-time skill."\n"All right, Patsy, let it go at that. And it\'s so, too. I suddenly remembered something Mona told me to tell you, and it affected my service."'
#  ...
#  'Solids are shapes that you can actually touch. They have three dimensions, which means that the have length, width and height. These shapes are what make up our daily life, and are very useful. Points on a solid must not be coplanar or colinear. The edge of solids are called the edge, and the surfaces are called faces. The corners, like angles and plane figures, are called vertices.\nA solid with only straight edges is called a polyhedron(pol-ee-HEE-dron). The plural form of polehedron is polyhedra(pol-ee-HEE-drah). Your chocolate bars are polyhedra, The Great Pyramids are polyhedra – a lot of things are. We will go into detail about them later.\nWhen dealing with these solid figures, there are two measurements we will need to know: the total surface area and the volume. The former is the sum of the faces of the solid; the latter is how big the solid is.'
#  'Animals are made of many cells. They eat things and digest them inside. Most animals can move. Only animals have brains (though not even all animals do; jellyfish, for example, do not have brains).\nAnimals are found all over the earth. They dig in the ground, swim in the oceans, and fly in the sky.\nHumans are a type of animal. So are dogs, cats, cows, horses, frogs, fish, and so on and on.\nAnimals can be divided into two main groups, vertebrates and invertebrates. Vertebrates can be further divided into mammals, fish, birds, reptiles, and amphibians. Invertebrates can be divided into arthropods (like insects, spiders, and crabs), mollusks, sponges, several different kinds of worms, jellyfish — and quite a few other subgroups. There are at least thirty kinds of invertebrates, compared to the five kinds of vertebrates. Vertebrates have a backbone, while invertebrates do not.'
#  nan]
# Word frequency:
# Excerpt
# the               49983
# and               26882
# of                25008
# to                21160
# a                 19071
#                   ...
# "molecule."           1
# grin—it               1
# Moon.                 1
# tapers;               1
# invertebrates,        1
# Name: count, Length: 74596, dtype: int64
#
#
# Column: British Words
# Unique values: ['traveller' nan 'sceptre' 'grey' 'aeroplane' 'axe' 'neighbour' 'draughts'
#  'behaviour' 'prologue' 'realise' 'instalment' 'quarrelled' 'colour'
#  'centre' 'favour' 'marvellous' 'smouldered, grey' 'travelled' 'honour'
#  'honoured' 'realise, neighbours' 'armour, armour' 'dialogue' 'offence'
#  'scrutinising' 'labours' 'sombre' 'travellers' 'favourite' 'woolly'
#  'tranquilly' 'labour, offence' 'favour, sceptre, sceptre' 'favours'
#  'labour' 'ploughman, plough' 'centres' 'metres' 'metres, metres, metres'
#  'amphitheatre, metres, metres, metres, amphitheatre' 'organised'
#  'colours' 'organisation' 'moulds' 'analyse' 'colour, colour' 'modelling'
#  'kilometres, metres, metres' 'signalling' 'analogues' 'kilometres'
#  'popularised' 'tonne' 'neighbour, kilometres' 'neighbouring'
#  'centimetre, centimetres, kilometres' 'fibre' 'recognise'
#  'kilometres, kilometres' 'grey, colour, colour, colour' 'millimetres'
#  'favourite, programme, colours' 'recognised' 'programme' 'realises'
#  'theatres' 'dialogues, dialogues' 'discs, discs'
#  'travelled, metres, kilometre' 'programmes' 'globalisation' 'woollen'
#  'kilometres, centimetre' 'vapour' 'analyses'
#  'disc, disc, disc, disc, disc' 'cypher, cypher, cyphers, cypher'
#  'fossilised, fossilise' 'levelling' 'quarrelling' 'travelled, travelled'
#  'analyses, analyses' 'discs' 'realised, realising' 'theatre, dialogue'
#  'labelled' 'fulfil' 'travelling' 'metre, metres' 'aeroplanes'
#  'apologise, realised' 'millilitres' 'judgement, judgement, judgement'
#  'colourful'
#  'litres, litres, litre, litre, litre, litres, litre, litre, litres'
#  'worshipped' 'odourless' 'practise' 'aeroplane, aeroplanes, aeroplane'
#  'favour, pyjama, favourite' 'realised' 'neighbours' 'chilli, chilli'
#  'grey, grey' 'moustache' 'disc' 'ploughman' 'fulfilment' 'theatre'
#  'moustaches, moustaches' 'grey, moustache' 'travelled, travelling'
#  'parlour' 'armour' 'labourer, neighbour, neighbour' 'harbour, neighbours'
#  'tranquillity' 'colours, colours, colours'
#  'marvellous, defences, accoutrements' 'sceptre, sceptre' 'odour' 'mouldy'
#  'coloured' 'sombre, colour, odours' 'defence'
#  'endeavour, mould, laboured'
#  'plough, ploughing, ploughed, plough, ploughed' 'sabre'
#  'organised, rumours' 'metre' 'labouring, colour' 'apologised'
#  'grey, disembowelling, harbour' 'clamour' 'fibre, pretences'
#  'groyne, harbour, groyne' 'honourable' 'reconnoitred' 'meagre'
#  'centre, coloured' 'emphasise' 'grey, centre, recognised'
#  'moulded, sabres' 'practising, recognise' 'discoloured' 'centre, rumour'
#  'instil' 'draught' 'clamouring' 'recognisable' 'labouring'
#  'coloured, favourites' 'neighbours, neighbouring, harbour'
#  'candour, candour' 'neighbour, honour' 'endeavoured' 'panelled'
#  'ploughed' 'labourer' 'dishevelled, grey' 'humour' 'mould, mould, mould'
#  'catalogue' 'sulphur' 'grammes, grammes, grammes'
#  'theatre, theatre, theatre' 'sulphate' 'sulphur, sulphur'
#  'sulphide, sulphides, sulphide, sulphide, sulphide, sulphate' 'sulphates'
#  'moulded' 'mould' 'sulphides' 'mould, mould' 'analogue' 'gramme'
#  'kilogrammes, kilogrammes' 'sulphur, draught' 'draughtsman'
#  'colour, coloured' 'sulphate, sulphate, sulphate' 'sulphate, sulphate'
#  'practising' 'dishonour' 'ploughing, plough' 'shovelling'
#  'fibres, fibres' 'grey, travelled' 'unrivalled' 'analysed'
#  'neighbourhood' 'criticise' 'dialogues, ardour' 'ploughing'
#  'traveller, travelled' 'offence, theatres' 'armour, travelled'
#  'parlour, honoured, parlour' 'vigour, humour' 'lustre' 'endeavours'
#  'baptised' 'smoulders' 'counsellor' 'neighbours, theatre'
#  'judgement, judgement' 'spectre' 'vapours, grey, grey' 'councillor'
#  'recognise, mediaeval' 'theatre, theatre' 'harbour' 'fillet' 'splendour'
#  'theatre, neighbour' 'offence, rumours' 'endeavoured, neutralise, odours'
#  'grey, neighbourhood' 'smouldering' 'honours' 'travellers, traveller'
#  'labour, neighbours' 'parlours, neighbours' 'carolled, colour'
#  'colour, vigour, homoeopathy' 'neighbouring, traveller' 'cosy'
#  'moustache, grey' 'favourite, favourite' 'draught, neighbouring'
#  'favoured' 'fillets' 'honourably, honour, honour' 'defenceless'
#  'pretence, marvelled' 'practised' 'jewelled' 'gaoler' 'dishevelled'
#  'sulphurous' 'kilogrammes' 'mitres' 'manoeuvred, axe' 'milligrammes'
#  'pyjamas' 'metres, metres' 'neutralised' 'jewellery' 'colourful, flavour'
#  'micrometres, millilitre, sulphide']
# Word frequency:
# British Words
# grey          25
# travelled     23
# colour        14
# centre        12
# axe           11
#               ..
# laboured       1
# ploughed,      1
# organised,     1
# metre          1
# sulphide       1
# Name: count, Length: 265, dtype: int64
#
#
# Column: Kaggle split
# Unique values: ['Train' 'Test' nan]
# Word frequency:
# Kaggle split
# Train    2834
# Test     1890
# Name: count, dtype: int64

# %% [markdown]
# What should we do to handle the class imbalace? (Source and MPAA Max Values)

# %%
df.to_csv('/Users/christine/code/ChristineSi/neuroCraft/raw_data/classification.csv', index=False)
